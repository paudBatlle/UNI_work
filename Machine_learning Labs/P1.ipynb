# %%
# LIBRARIES USED IN THIS PRACTICE:

# import numpy as np # NumPy is the fundamental package for scientific computing with Python.
# from matplotlib import pyplot as plt # Matplotlib is a Python 2D plotting library.
# from sklearn import datasets # sklearn is a very extense and efficient machine learning library.

# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d.axes3d import Axes3D
import math

# %% [markdown]
# ## Exercise 2 (Exercise 1 is in the pdf)

# %%
from numpy.ma.core import size
def kmeans(X,k):   
    d = []*k*X
    x=X[:,0]
    y=X[:,1]
    C = np.array([0,0],[0,0],[0,0])
    llargada = np.arange(len(x))
    #min =. array que realciona els punts amb el seu cluster/centre
    #calculem els centres
    for a in range(k):    
        index = [np.random.choice(llargada,None,False)]
        C[a] = X[index]
    while C != C:       #bucle fins que coincideixin els centres
        #calculem distancies i les guardem a la matriu
        for i in range(x):
            for j in range(k):
                d[i,j] = np.linalg.norm(X[X-C[])
        #relacionar cada punt amb el ceu centre
        #recalcular centre
        



#fer la taula i buscar les desitancies als centres
#assignar cada punt a un cluster amb els seu centre
#calcular centres (fer mitjana dels punts)
#tornar a calcular distancies i repetir
    return C,d
# Out:
#   File "<ipython-input-19-6f52867639d2>", line 19
#     return C,d
#          ^
# SyntaxError: invalid syntax

# %%
from sklearn.datasets import make_blobs

#Create dataset:
n_samples = 1500
random_state = 20
k=3
X, y = make_blobs(n_samples=n_samples, random_state=random_state, centers=3)

print(X.shape)
#Plot generated points:
plt.scatter(X[:, 0], X[:, 1])

#Your code here.
#kmeans(X,k)

x=X[:,0]
y=X[:,1]
C = [[0,0],[0,0],[0,0]]
llargada = np.arange(len(x))
for a in range(k):    
    index = [np.random.choice(llargada,None,False)]
    C[a] = X[index]
print(x)
print(C)
# Out:
# (1500, 2)
# [ 1.4329872  -9.2234713   7.48232622 ... -9.28603864  8.89207874
#   1.55036957]
# [array([[6.60242493, 6.75874601]]), array([[-10.08704368,   4.57888891]]), array([[-9.27940754,  3.03661512]])]

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# We start importing sklearn and generating the dataset with the function make_bolbs:

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

#Create dataset:
n_samples = 1500
random_state = 20
X, y = make_blobs(n_samples=n_samples, random_state=random_state, centers=4)

#Plot generated points:
fig = plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1])
plt.title('Dataset')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %% [markdown]
# We now call the KMeans function from sklearn to do clustering with 2 clusters:

# %%
y_pred = KMeans(n_clusters=2).fit_predict(X)

fig = plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1])
plt.title('Predicted clusters')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %% [markdown]
# a) Do the same for different number of clusters (e.g. N=2,4,6). Explain the results.

# %%
# Your code here.
#3
y_pred = KMeans(n_clusters=3).fit_predict(X)
fig = plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1])
plt.title('Predicted clusters')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %%
#4
y_pred = KMeans(n_clusters=4).fit_predict(X)
fig = plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1])
plt.title('Predicted clusters')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %%
#6
y_pred = KMeans(n_clusters=6).fit_predict(X)
fig = plt.figure(figsize=(5,5))
plt.scatter(X[:, 0], X[:, 1])
plt.title('Predicted clusters')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %% [markdown]
# We now introduce a transformation in our dataset to change it's shape:

# %%
#Apply the transformation to our dataset
transformation = [[0.60834549, -0.63667341], [-0.40887718, 0.85253229]]
X_transf = np.dot(X, transformation)

#Plot generated points:
fig = plt.figure(figsize=(5,5))
plt.scatter(X_transf[:, 0], X_transf[:, 1])
plt.title('Transformed dataset')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %% [markdown]
# b) Do clustering on this new dataset. What do you observe? Why?

# %%
#Your code here.
#6
y_pred = KMeans(n_clusters=6).fit_predict(X_transf)
fig = plt.figure(figsize=(5,5))
plt.scatter(X_transf[:, 0], X_transf[:, 1])
plt.title('Predicted clusters')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %% [markdown]
# Finally, we create another dataset where the variance of the different bulbs is different:

# %%
# Create dataset with different variance
X_varied, y_varied = make_blobs(n_samples=n_samples,
                                cluster_std=[1.0, 2.5, 0.5],
                                random_state=random_state)

fig = plt.figure(figsize=(5,5))
plt.scatter(X_varied[:, 0], X_varied[:, 1])
plt.title('Transformed dataset')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()

# %% [markdown]
# c) Do clustering on this new dataset. What do you observe?

# %%
#Your code here.
#6
y_pred = KMeans(n_clusters=2).fit_predict(X_varied)
fig = plt.figure(figsize=(5,5))
plt.scatter(X_varied[:, 0], X_varied[:, 1])
plt.title('Predicted clusters')
plt.xlabel('x_1')
plt.ylabel('x_2')
plt.show()
